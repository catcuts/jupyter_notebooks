# %% [markdown]
#   -  **完成了上周安排的哪些工作**
#
#   （暂无，上周未系统安排）
#   <br><br>
#   -  **未完成上周安排的哪些工作，和导致未完成的障碍**
#
#   （暂无，上周未系统安排）
#   <br><br>
#   -  **额外完成了哪些上周未安排的工作**
#
#   （暂无，上周未系统安排）
#   <br><br>
#   -  **准备下周要完成哪些工作**
#
#       1. **树莓派只读系统测试（注：开发已完毕）**
#
#           - 测试：系统抗断电能力，导入数据是否异常（**备忘**：别忘了为系统添加周期备份数据库任务）
#           - 测试完毕，为库存和客户升级（**备忘**：对客户，别忘了先备份数据！）
#           - 整理开发文档，便于今后查阅
#           - **应交付**：测试报告、仓库和客户已升级确认、开发文档
# <br><br>
#       2. **香橙派只读系统开发与测试**
#
#           - 开发：系统挂载为只读，部分运行程序和数据库的目录挂载为读写，[参考](https://wiki.debian.org/ReadonlyRoot#Enable_readonly_root)
#           - 测试：安排测试，并根据测试反馈进行修正
#           - 测试完毕，为美国客户升级（**备忘**：别忘了先备份数据！）
#           - 整理：整理开发文档
#           - **应交付**：测试报告、客户已升级确认、开发文档
# <br><br>
#       3. **云平台后端与前端开发**
#           全部工作分为：阅读已有源码、明确医疗项目需求、任务安排、执行、跟踪、交付。
#           下周主要工作为：
#           - 阅读已有源码（**备忘**：与张工多交流，他是作者）
#           - 明确医疗项目需求（**备忘**：与阿秋多交流，他是产品经理）
#           - 云平台开发任务安排到禅道（**备忘**：向会用的人请教）
#           - **应交付**：交流纪要（如需）、在禅道上的相关任务列表
#   <br><br>
#   -  **其他任何事项（意见建议、感想备忘、吐槽抱怨皆可）**
#
#   （暂无）
