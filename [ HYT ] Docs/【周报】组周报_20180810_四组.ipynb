# %% [markdown]
# ## <center>四组周报<br>20180810</center>
#
# ___
#
# ### <span style='color: #dd4b39;'>已完成的上周工作</span>
#
# 　　以下是本组上周已完成的工作内容概况：
#
# <table>
#   <thead>
#     <tr>
#       <th style='text-align: center;'>项目</th>
#       <th style='text-align: center;'>子项目</th>
#       <th style='text-align: center;'>工作内容</th>
#       <th style='text-align: center;'>详情</th>
#       <th style='text-align: center;'>负责组员</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td rowspan="4" style='text-align: center;'>医疗项目</td>
#     </tr>
#     <tr>
#       <td style='text-align: center;'>7寸病床分机</td>
#       <td style='text-align: left;'>
#           1. <span style="font-weight: bold;">（20%->30%）</span>分机测试反馈 bug（解决了 升级界面的 bug）<br>
#           2. <span style="font-weight: bold; color: #dd4b39;">（01%->01%）等待 DP 的协助，以解决通讯类 bug 和 完善分机升级功能</span><br>
#           3. <span style="font-weight: bold;">（01%->10%）</span>分机告警、事件、动作的逻辑设计和文档编写
#       </td>
#       <td style='text-align: center;'>详见 <a href="#1.-病床分机完成度详情">1</a></td>
#       <td style='text-align: center;'>黄培添</td>
#     </tr>
#     <tr>
#       <td style='text-align: center;'>服务器<br>（云平台）</td>
#       <td style='text-align: left;'>
#           1. <span style="font-weight: bold;">（02%->90%）</span>阅读 vig-9002 源码和文档<br>
#           2. <span style="font-weight: bold;">（02%->02%）</span>理解业务和逻辑需求，然后在禅道上部署任务<br>
#           3. <span style="font-weight: bold;">（02%->02%）</span>根据任务部署结果，得出一些阶段性成果的时间表<br>
#           4. <span style="font-weight: bold;">（ - -%->- -%）</span>参与讨论医疗项目的通信协议（用 FS 实现还是私有协议）<br>
#           5. <span style="font-weight: bold;">（ - -%->- -%）</span>参与外包相关技术讨论。
#       </td>
#       <td style='text-align: center;'>详见 <a href="#2.-云平台完成度详情">2</a></td>
#       <td style='text-align: center;'>刘腾辉</td>
#     </tr>
#     <tr>
#       <td style='text-align: center;'>人脸检测与识别通用库</td>
#       <td style='text-align: left;'>
#           1. <span style="font-weight: bold;">（99->%99%）</span>人脸检测功能（有人脸出现，则立即响应）<br>
#           2. <span style="font-weight: bold;">（02%->99%）</span>人脸定位功能（定位该人脸的位置）<br>
#           3. <span style="font-weight: bold;">（02%->99%）</span>人脸识别功能（数据降维，提取特征）<br>
#           （<!>但是：性能不满足要求，下周需要优化）
#       </td>
#       <td style='text-align: center;'>详见 <a href="#3.-人脸库完成度详情">3</a></td>
#       <td style='text-align: center;'>张圣祥</td>
#     </tr>
#     <tr>
#       <td style='text-align: center;'>iptalk1.0项目</td>
#       <td style='text-align: center;'>TB-8000S<br>（iptalk树莓派服务器）</td>
#       <td style='text-align: left;'>
#           1. <span style="font-weight: bold;">（ - -%->- -%）</span>培训了技术支持（现场演示 + 复习视频）<br>
#           2. <span style="font-weight: bold;">（ - -%->- -%）</span>协助技术支持解决内蒙古客户树莓派问题
#       </td>
#       <td style='text-align: center;'>-</td>
#       <td style='text-align: center;'>刘腾辉</td>
#     </tr>
#     <tr>
#       <td style='text-align: center;'>智能网关项目</td>
#       <td style='text-align: center;'>VIG-9002<br>（智能网关服务器）</td>
#       <td style='text-align: left;'>
#           1. <span style="font-weight: bold;">（80%->99%）</span>香橙派只读系统部署与测试<br>
#           2. <span style="font-weight: bold;">（80%->99%）</span>一个自动部署该系统的脚本<br>
#           3. <span style="font-weight: bold;">（ - -%->- -%）</span>为美国客户升级<br>
#           4. <span style="font-weight: bold;">（ - -%->- -%）</span>整理开发文档<br>
#           5. <span style="font-weight: bold;">（ - -%->- -%）</span>参与关于 VIG9002 空中协议通信优化的讨论<br>
#           6. <span style="font-weight: bold;">（ - -%->- -%）</span>参与关于 VIG9002 空中协议通信优化的实施（具体要改哪部分源码）
#       </td>
#       <td style='text-align: center;'>详见 <a href="#4.-智能网关项目详情">4</a></td>
#       <td style='text-align: center;'>刘腾辉</td>
#     </tr>
#   </tbody>
# </table>
#
# ___
#
# ### <span style='color: #dd4b39;'>下周准备完成的工作</span>
#
# 　　以下是本组下周准备完成的工作内容概况：
#
# <table>
#   <thead>
#     <tr>
#       <th style='text-align: center;'>项目</th>
#       <th style='text-align: center;'>子项目</th>
#       <th style='text-align: center;'>工作内容</th>
#       <th style='text-align: center;'>详情</th>
#       <th style='text-align: center;'>负责组员</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td rowspan="4" style='text-align: center;'>医疗项目</td>
#     </tr>
#     <tr>
#       <td style='text-align: center;'>7寸病床分机</td>
#       <td style='text-align: left;'>
#           按优先级：<br>
#           1. 分机通信类 bug（在 DP 有协助的情况下）<br>
#           2. 分机告警、事件、动作的逻辑开发（在 DP 没有回音的情况下）<br>
#           3. 分机其他 bug（穿插或靠后进行）
#       </td>
#       <td style='text-align: center;'>-</td>
#       <td style='text-align: center;'>黄培添</td>
#     </tr>
#     <tr>
#       <td style='text-align: center;'>服务器<br>（云平台）</td>
#       <td style='text-align: left;'>
#           1. 分解任务，制定时间表<br>
#           2. web/api 相关工作（阅读 nebd 和 jsonpath 使用文档；原先代码的试运行；确定api协议等）<br>
#           3. vimp 通信相关工作（阅读协议文档；编写告警、事件、动作等相关文档等）<br>
#           4. web 前端相关工作
#       </td>
#       <td style='text-align: center;'>详见 <a href="#5.-云平台下周计划">5</a></td>
#       <td style='text-align: center;'>刘腾辉</td>
#     </tr>
#     <tr>
#       <td style='text-align: center;'>人脸检测与识别通用库</td>
#       <td style='text-align: left;'>
#           1. 人脸检测与识别通用库性能的提升
#       </td>
#       <td style='text-align: center;'>-</td>
#       <td style='text-align: center;'>张圣祥</td>
#     </tr>
#     <tr>
#       <td style='text-align: center;'>iptalk1.0项目</td>
#       <td style='text-align: center;'>TB-8000S<br>（iptalk树莓派服务器）</td>
#       <td style='text-align: left;'>
#           1. 为车间和客户提供升级技术支持
#       </td>
#       <td style='text-align: center;'>-</td>
#       <td style='text-align: center;'>刘腾辉</td>
#     </tr>
#     <tr>
#       <td style='text-align: center;'>智能网关项目</td>
#       <td style='text-align: center;'>VIG-9002<br>（智能网关服务器）</td>
#       <td style='text-align: left;'>
#           1. 协助呼叫器与手表开发者联调<br>
#           2. 接收测试部反馈问题并解决<br>
#           3. 香橙派只读系统测试和完善<br>
#           4. 为美国客户升级<br>
#           5. 整理开发文档
#       </td>
#       <td style='text-align: center;'>-</td>
#       <td style='text-align: center;'>刘腾辉</td>
#     </tr>
#   </tbody>
# </table>
#
# ___
# ___
#
# ### 详
#
# #### 1. **病床分机完成度详情**
#
# 　　DP 迟迟没有提供支持。在群上喊也没用。不搭理。
#
# #### 2. **云平台完成度详情**
#
# 　　基本按照上周安排进行。只是：
#
# - 周三下午请假；
# <br><br>
# - 周四原计划分解任务和制定时间表，实际：
#
#     1. 协助技术支持解决内蒙古客户树莓派问题——上午
#     2. 参与关于 VIG9002 空中协议通信优化的讨论——下午
#     3. 参与关于 VIG9002 空中协议通信优化的实施（具体要改哪部分源码）——晚上
# <br><br>
# - 周五早上参与讨论医疗项目的通信协议（用 FS 实现还是私有协议）；下午参与外包相关技术讨论。
# <br><br>
# - 附：上周原计划：
#
# <table>
#   <thead>
#     <tr>
#       <th style='text-align: center;'></th>
#       <th style='text-align: center;'>五</th>
#       <th style='text-align: center;'>一</th>
#       <th style='text-align: center;'>二</th>
#       <th style='text-align: center;'>三</th>
#       <th style='text-align: center;'>四</th>
#       <th style='text-align: center;'>五</th>
#       <th style='text-align: center;'>六</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style='text-align: left;'>上午</td>
#       <td style='text-align: left;'>部署了香橙派只读系统<br>给测试部测了n次</td>
#       <td style='text-align: left;'>完成香橙派只读系统<br>部署与测试（上）</td>
#       <td style='text-align: left;'>本周云平台开发任务：<br>阅读源码</td>
#       <td style='text-align: left;'>本周云平台开发任务：<br>明确需求</td>
#       <td style='text-align: left;'>本周云平台开发任务：<br>时间表</td>
#       <td style='text-align: left;'>本周云平台开发任务：<br>缓冲 或 按时间表执行</td>
#       <td rowspan="2" style='text-align: left;'>周报预计<br>写于当天<br>故周六计入<br>下周周报</td>
#     </tr>
#     <tr>
#       <td style='text-align: left;'>下午</td>
#       <td style='text-align: left;'>接收测试反馈，<br>完善香橙派只读系统</td>
#       <td style='text-align: left;'>完成香橙派只读系统<br>部署与测试（下）</td>
#       <td style='text-align: left;'>本周云平台开发任务：<br>阅读源码</td>
#       <td style='text-align: left;'>本周云平台开发任务：<br>安排禅道</td>
#       <td style='text-align: left;'>本周云平台开发任务：<br>缓冲 或 按时间表执行</td>
#       <td style='text-align: left;'>本周云平台开发任务：<br>缓冲 或 按时间表执行</td>
#     </tr>
#   </tbody>
# </table>
#
# #### 3. **人脸库完成度详情**
#
# 　　人脸库的三个核心函数完成，但是特征占用存储空间较大，需要优化。
#
# #### 4. **智能网关项目详情**
#
# 　　只读系统部署完毕，内部程序正常运行，测试部正在测试
# 　　（已在非呼叫状态下测 30 次无异常）
#
# #### 5. **云平台下周计划**
#
# <table>
#   <thead>
#     <tr>
#       <th style='text-align: center;'></th>
#       <th style='text-align: center;'>六</th>
#       <th style='text-align: center;'>一</th>
#       <th style='text-align: center;'>二</th>
#       <th style='text-align: center;'>三</th>
#       <th style='text-align: center;'>四</th>
#       <th style='text-align: center;'>五</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style='text-align: left;'>上午</td>
#       <td style='text-align: left;'>分解任务<br>制定时间表<br>初步</td>
#       <td style='text-align: left;'>阅读 nebd <br>和 jsonpath</td>
#       <td style='text-align: left;'>阅读协议文档</td>
#       <td style='text-align: left;'>编写告警、<br>事件、<br>动作等相关文档</td>
#       <td style='text-align: left;'>缓冲区</td>
#       <td rowspan="2" style='text-align: left;'>周报预计<br>写于当天<br>故周五计入<br>下周周报</td>
#     </tr>
#     <tr>
#       <td style='text-align: left;'>下午</td>
#       <td style='text-align: left;'>确定分解任务合理性<br>确定时间表可行性<br>后执行</td>
#       <td style='text-align: left;'>试运行原有的<br> web/api 代码</td>
#       <td style='text-align: left;'>理解既定<br>业务数据模型</td>
#       <td style='text-align: left;'>确定 api 协议</td>
#       <td style='text-align: left;'>缓冲区</td>
#     </tr>
#   </tbody>
# </table>
#
# 　　注：缓冲区可能用于：
#
# 1. 为车间和客户的部署提供技术支持等额外事项。
#
# 2. 随机出现的 VIG9002 网关维护工作。
