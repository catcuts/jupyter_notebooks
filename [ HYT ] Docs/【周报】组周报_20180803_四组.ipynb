# %% [markdown]
# ## <center>四组周报<br>20180803</center>
#
# ___
#
# ### <span style='color: #dd4b39;'>已完成的上周工作</span>
#
# 　　以下是本组上周已完成的工作内容概况：
#
# <table>
#   <thead>
#     <tr>
#       <th style='text-align: center;'>项目</th>
#       <th style='text-align: center;'>子项目</th>
#       <th style='text-align: center;'>工作内容</th>
#       <th style='text-align: center;'>详情</th>
#       <th style='text-align: center;'>负责组员</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td rowspan="4" style='text-align: center;'>医疗项目</td>
#     </tr>
#     <tr>
#       <td style='text-align: center;'>7寸病床分机</td>
#       <td style='text-align: left;'>
#           1. <span style="font-weight: bold;">（20%）</span>完成分机测试反馈的 10 个 bug 中优先级较高的 5 个<br>
#          　<span style="font-weight: bold;">（99%）</span>自主构建的 UI 库移植到分机，避免过度依赖 DP<br>
#           2. <span style="font-weight: bold;">（ - -%）</span>同时关注 DP 的协助进展，以完善分机升级功能<br>
#           3. <span style="font-weight: bold;">（ - -%）</span>并关注分机告警、事件、动作的逻辑设计
#       </td>
#       <td style='text-align: center;'>详见 <a href="#1.-病床分机完成度详情">1</a></td>
#       <td style='text-align: center;'>黄培添</td>
#     </tr>
#     <tr>
#       <td style='text-align: center;'>服务器<br>（云平台）</td>
#       <td style='text-align: left;'>
#           1. <span style="font-weight: bold;">（02%）</span>阅读 vig-9002 源码和文档<br>
#           2. <span style="font-weight: bold;">（00%）</span>理解业务和逻辑需求，然后在禅道上部署任务<br>
#           3. <span style="font-weight: bold;">（00%）</span>根据任务部署结果，得出一些阶段性成果的时间表
#       </td>
#       <td style='text-align: center;'>详见 <a href="#2.-云平台完成度详情">2</a></td>
#       <td style='text-align: center;'>刘腾辉</td>
#     </tr>
#     <tr>
#       <td style='text-align: center;'>人脸检测与识别通用库</td>
#       <td style='text-align: left;'>
#           1. <span style="font-weight: bold;">（30%）</span>人脸检测功能（有人脸出现，则立即响应）<br>
#           2. <span style="font-weight: bold;">（00%）</span>人脸定位功能（定位该人脸的位置）<br>
#           3. <span style="font-weight: bold;">（00%）</span>人脸识别功能（数据降维，提取特征）
#       </td>
#       <td style='text-align: center;'>详见 <a href="#3.-人脸库完成度详情">3</a></td>
#       <td style='text-align: center;'>张圣祥</td>
#     </tr>
#     <tr>
#       <td style='text-align: center;'>iptalk1.0项目</td>
#       <td style='text-align: center;'>TB-8000S<br>（iptalk树莓派服务器）</td>
#       <td style='text-align: left;'>
#           1. <span style="font-weight: bold;">（99%）</span>树莓派只读系统测试<br>
#           2. <span style="font-weight: bold;">（99%）</span>为仓库和客户升级<br>
#           3. <span style="font-weight: bold;">（99%）</span>整理开发文档
#       </td>
#       <td style='text-align: center;'>详见 <a href="#4.-树莓派只读系统完成度详情">4</a></td>
#       <td style='text-align: center;'>刘腾辉</td>
#     </tr>
#     <tr>
#       <td style='text-align: center;'>智能网关项目</td>
#       <td style='text-align: center;'>VIG-9002<br>（智能网关服务器）</td>
#       <td style='text-align: left;'>
#           1. <span style="font-weight: bold;">（80%）</span>香橙派只读系统部署与测试<br>
#           2. <span style="font-weight: bold;">（00%）</span>为美国客户升级<br>
#           3. <span style="font-weight: bold;">（10%）</span>整理开发文档
#       </td>
#       <td style='text-align: center;'>详见 <a href="#5.-香橙派只读系统完成度详情">5</a></td>
#       <td style='text-align: center;'>刘腾辉</td>
#     </tr>
#   </tbody>
# </table>
#
# ___
#
# ### <span style='color: #dd4b39;'>下周准备完成的工作</span>
#
# 　　以下是本组下周准备完成的工作内容概况：
#
# <table>
#   <thead>
#     <tr>
#       <th style='text-align: center;'>项目</th>
#       <th style='text-align: center;'>子项目</th>
#       <th style='text-align: center;'>工作内容</th>
#       <th style='text-align: center;'>详情</th>
#       <th style='text-align: center;'>负责组员</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td rowspan="4" style='text-align: center;'>医疗项目</td>
#     </tr>
#     <tr>
#       <td style='text-align: center;'>7寸病床分机</td>
#       <td style='text-align: left;'>
#           按优先级：<br>
#           1. 分机通信类 bug（在 DP 有协助的情况下）<br>
#           2. 分机告警、事件、动作的逻辑开发（在 DP 没有回音的情况下）<br>
#           3. 分机其他 bug（穿插或靠后进行）
#       </td>
#       <td style='text-align: center;'>-</td>
#       <td style='text-align: center;'>黄培添</td>
#     </tr>
#     <tr>
#       <td style='text-align: center;'>服务器<br>（云平台）</td>
#       <td style='text-align: left;'>
#           1. 阅读 vig-9002 源码和文档<br>
#           2. 理解业务和逻辑需求，然后在禅道上部署任务<br>
#           3. 根据任务部署结果，得出一些阶段性成果的时间表<br>
#           4. 为分机分解关于实现 VIMP 协议的任务，更新设备告警、事件、动作编码
#       </td>
#       <td style='text-align: center;'>-</td>
#       <td style='text-align: center;'>刘腾辉</td>
#     </tr>
#     <tr>
#       <td style='text-align: center;'>人脸检测与识别通用库</td>
#       <td style='text-align: left;'>
#           1. 人脸定位功能开发<br>
#           2. 人脸识别功能开发<br>
#           3. 人脸检测功能进一步完善
#       </td>
#       <td style='text-align: center;'>-</td>
#       <td style='text-align: center;'>张圣祥</td>
#     </tr>
#     <tr>
#       <td style='text-align: center;'>iptalk1.0项目</td>
#       <td style='text-align: center;'>TB-8000S<br>（iptalk树莓派服务器）</td>
#       <td style='text-align: left;'>
#           1. 为车间和客户提供升级技术支持
#       </td>
#       <td style='text-align: center;'>-</td>
#       <td style='text-align: center;'>刘腾辉</td>
#     </tr>
#     <tr>
#       <td style='text-align: center;'>智能网关项目</td>
#       <td style='text-align: center;'>VIG-9002<br>（智能网关服务器）</td>
#       <td style='text-align: left;'>
#           1. 香橙派只读系统测试和完善<br>
#           2. 为美国客户升级<br>
#           3. 整理开发文档
#       </td>
#       <td style='text-align: center;'>-</td>
#       <td style='text-align: center;'>刘腾辉</td>
#     </tr>
#   </tbody>
# </table>
#
# ___
# ___
#
# ### 详
#
# #### 1. **病床分机完成度详情**
#
# 　　**未完成原因**：本周主要进行 UI 库的移植，工作量较大。
#
# 　　（UI 库移植完成，可以不用再依赖 DP，加快一些关于 UI 的 bug 的解决）
#
# #### 2. **云平台完成度详情**
#
# 　　**未开始原因**：
# - 本周主要进行树莓派和香橙派的只读系统构建工作，包括：一键部署脚本和相关文档、镜像等。
#
# - 上周没有考虑到要为两种只读系统的构建分别做一个自动化脚本（它们的编写和自己测试分别花去了 1 天时间）
#
# - 周一下午有客户的树莓派服务器出现问题，前去解决，已解决（原因是空间不足，我给它挂载了硬盘，部署了自动定时备份和清理任务）
#
# #### 3. **人脸库完成度详情**
#
# 　　**未完成原因**：先前没有考虑程序健壮性，故多花了些时间来提高该性能。
#
# #### 4. **树莓派只读系统完成度详情**
#
#   - 测试：系统抗断电能力正常（100次呼叫中断电，100次通话中断电，正常率达到99%），导入数据无异常，并为系统添加周期备份数据库任务
#   - 已整理开发文档，便于今后查阅
#   - 已编写一个自动构建脚本，适应在2种情况（车间生产中和用户使用中）无损构建该只读系统
#   - 已经（通过戴工）通知车间可以升级，已经（通过李德平和连佳伟）关注树莓派客户反馈（当出现相关问题时，可以升级为只读系统）
#   - **已交付**：
#     - 测试报告——已经（通过戴工）通知测试部整理，会跟进
#     - 车间和客户已升级确认——已通知车间和客户，会持续得到确认
#     - 部署文档——已悉数上传至 ownCloud，包括：
#       - 1个该系统的[镜像文件](http://192.168.38.165:8080/index.php/f/67772)（.img 用于在 windows 下还原）
#       - 1个该系统的[备份文件](http://192.168.38.165:8080/index.php/f/67760)（.gz 用于在 linux 下还原）
#       - 1篇[部署指南](http://192.168.38.165:8080/index.php/f/67762)
#       - 1段[指导视频](http://192.168.38.165:8080/index.php/f/67764)
#       - 1个[自动构建程序包](http://192.168.38.165:8080/index.php/f/67763)
#
# #### 5. **香橙派只读系统完成度详情**
#
# 　　**未完成原因**：
#
# - 上周没有考虑到要为两种只读系统的构建分别做一个自动化脚本（它们的编写和自己测试分别花去了 1 天时间）
#
# - 周一下午有客户的树莓派服务器出现问题，前去解决，已解决（原因是空间不足，我给它挂载了硬盘，部署了自动定时备份和清理任务）
