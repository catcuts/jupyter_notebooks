# %% [markdown]
# ## <center>四组周报<br>20180817</center>
#
# ___
#
# ### <span style='color: #dd4b39;'>已完成的上周工作</span>
#
# 　　以下是本组上周已完成的工作内容概况：
#
# <table>
#   <thead>
#     <tr>
#       <th style='text-align: center;'>项目</th>
#       <th style='text-align: center;'>子项目</th>
#       <th style='text-align: center;'>工作内容</th>
#       <th style='text-align: center;'>详情</th>
#       <th style='text-align: center;'>负责组员</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td rowspan="4" style='text-align: center;'>医疗项目</td>
#     </tr>
#     <tr>
#       <td style='text-align: center;'>7寸病床分机</td>
#       <td style='text-align: left;'>
#           1. <span style="font-weight: bold;">（30%->100%）</span>（上周分配的）分机测试反馈 bug（包括分机升级 ui 类 bug）<br>
#           2. <span style="font-weight: bold;">（01%->01%）等待 DP 的协助，以解决通讯类 bug</span><br>
#           3. <span style="font-weight: bold;">（10%->15%）</span>分机告警、事件、动作的逻辑设计和文档编写（7.27会讨论内容）
#       </td>
#       <td style='text-align: center;'>详见 <a href="#1.-病床分机完成度详情">1</a></td>
#       <td style='text-align: center;'>黄培添</td>
#     </tr>
#     <tr>
#       <td style='text-align: center;'>服务器<br>（云平台）</td>
#       <td style='text-align: left;'>
#           1. <span style="font-weight: bold;">（90%->90%）</span>阅读 vig-9002 源码和文档<br>
#           2. <span style="font-weight: bold;">（02%->33%）</span>理解业务和逻辑需求，然后在禅道上部署任务<br>
#           3. <span style="font-weight: bold;">（02%->33%）</span>根据任务部署结果，得出一些阶段性成果的时间表<br>
#       </td>
#       <td style='text-align: center;'>详见 <a href="#2.-云平台完成度详情">2</a></td>
#       <td style='text-align: center;'>刘腾辉</td>
#     </tr>
#     <tr>
#       <td style='text-align: center;'>人脸检测与识别通用库</td>
#       <td style='text-align: left;'>
#           1. <span style="font-weight: bold;">（99%->100%）</span>优化完成，已形成第一版<br>
#       </td>
#       <td style='text-align: center;'>详见 <a href="#3.-人脸库完成度详情">3</a></td>
#       <td style='text-align: center;'>张圣祥</td>
#     </tr>
#     <tr>
#       <td style='text-align: center;'>iptalk1.0项目</td>
#       <td style='text-align: center;'>TB-8000S<br>（iptalk树莓派服务器）</td>
#       <td style='text-align: left;'>
#           1. <span style="font-weight: bold;">（ - -%->- -%）</span>协助技术支持解决江苏泰州客户树莓派问题
#       </td>
#       <td style='text-align: center;'>-</td>
#       <td style='text-align: center;'>刘腾辉</td>
#     </tr>
#     <tr>
#       <td style='text-align: center;'>智能网关项目</td>
#       <td style='text-align: center;'>VIG-9002<br>（智能网关服务器）</td>
#       <td style='text-align: left;'>
#           1. <span style="font-weight: bold;">（ - -%->100%）</span>与多方开发者联调，解决手表不能注册、呼叫器不能呼叫的问题<br>
#           2. <span style="font-weight: bold;">（ - -%->100%）</span>客户反馈 VIG9002 不能设置网络，已发现问题所在，正在修改<br>
#           3. <span style="font-weight: bold;">（ - -%->90%）</span>解决手表不能注册和收到呼叫信息的问题 <br>
#       </td>
#       <td style='text-align: center;'>-</td>
#       <td style='text-align: center;'>刘腾辉</td>
#     </tr>
#   </tbody>
# </table>
#
# ___
#
# ### <span style='color: #dd4b39;'>下周准备完成的工作</span>
#
# 　　以下是本组下周准备完成的工作内容概况：
#
# <table>
#   <thead>
#     <tr>
#       <th style='text-align: center;'>项目</th>
#       <th style='text-align: center;'>子项目</th>
#       <th style='text-align: center;'>工作内容</th>
#       <th style='text-align: center;'>详情</th>
#       <th style='text-align: center;'>负责组员</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td rowspan="4" style='text-align: center;'>医疗项目</td>
#     </tr>
#     <tr>
#       <td style='text-align: center;'>7寸病床分机</td>
#       <td style='text-align: left;'>
#           按优先级：<br>
#           1. 分机通信类 bug（在 DP 有协助的情况下）<br>
#           2. 分机告警、事件、动作的逻辑开发（在 DP 没有回音的情况下）<br>
#           3. 分机本周提出的新 bug（穿插或靠后进行）
#       </td>
#       <td style='text-align: center;'>-</td>
#       <td style='text-align: center;'>黄培添</td>
#     </tr>
#     <tr>
#       <td style='text-align: center;'>服务器<br>（云平台）</td>
#       <td style='text-align: left;'>
#           1. 分解其他任务，制定时间表<br>
#           2. web/api 按时间表开发<br>
#           3. vimp 通信相关工作（阅读协议文档；编写告警、事件、动作等相关文档等）<br>
#           4. web 前端相关工作
#       </td>
#       <td style='text-align: center;'>详见 <a href="#4.-云平台下周计划">4</a></td>
#       <td style='text-align: center;'>刘腾辉</td>
#     </tr>
#     <tr>
#       <td style='text-align: center;'>人脸检测与识别通用库</td>
#       <td style='text-align: left;'>
#           1. 第二版工作
#       </td>
#       <td style='text-align: center;'>-</td>
#       <td style='text-align: center;'>张圣祥</td>
#     </tr>
#     <tr>
#       <td style='text-align: center;'>iptalk1.0项目</td>
#       <td style='text-align: center;'>TB-8000S<br>（iptalk树莓派服务器）</td>
#       <td style='text-align: left;'>
#           1. 为车间和客户提供升级技术支持
#       </td>
#       <td style='text-align: center;'>-</td>
#       <td style='text-align: center;'>刘腾辉</td>
#     </tr>
#     <tr>
#       <td style='text-align: center;'>智能网关项目</td>
#       <td style='text-align: center;'>VIG-9002<br>（智能网关服务器）</td>
#       <td style='text-align: left;'>
#           1. 协助呼叫器与手表开发者联调<br>
#           2. 接收测试部反馈问题并解决<br>
#           3. 香橙派只读系统测试和完善<br>
#           4. 为美国客户升级<br>
#           5. 整理开发文档
#       </td>
#       <td style='text-align: center;'>-</td>
#       <td style='text-align: center;'>刘腾辉</td>
#     </tr>
#   </tbody>
# </table>
#
# ___
# ___
#
# ### 详
#
# #### 1. **病床分机完成度详情**
#
# 　　上周之前提出的 bug 都要已经解决，并发布了一个新版本给测试部测试。
#
# 　　同时，本周又有新的 bug 提出；DP 仍然无消息。
#
# #### 2. **云平台完成度详情**
#
# 　　VIG9002 的维护工作占了大部分，云平台只分解了 API 任务。
#
# - 附：上周原计划：
#
# <table>
#   <thead>
#     <tr>
#       <th style='text-align: center;'></th>
#       <th style='text-align: center;'>六</th>
#       <th style='text-align: center;'>一</th>
#       <th style='text-align: center;'>二</th>
#       <th style='text-align: center;'>三</th>
#       <th style='text-align: center;'>四</th>
#       <th style='text-align: center;'>五</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style='text-align: left;'>上午</td>
#       <td style='text-align: left;'>分解任务<br>制定时间表<br>初步</td>
#       <td style='text-align: left;'>阅读 nebd <br>和 jsonpath</td>
#       <td style='text-align: left;'>阅读协议文档</td>
#       <td style='text-align: left;'>编写告警、<br>事件、<br>动作等相关文档</td>
#       <td style='text-align: left;'>缓冲区</td>
#       <td rowspan="2" style='text-align: left;'>周报预计<br>写于当天<br>故周五计入<br>下周周报</td>
#     </tr>
#     <tr>
#       <td style='text-align: left;'>下午</td>
#       <td style='text-align: left;'>确定分解任务合理性<br>确定时间表可行性<br>后执行</td>
#       <td style='text-align: left;'>试运行原有的<br> web/api 代码</td>
#       <td style='text-align: left;'>理解既定<br>业务数据模型</td>
#       <td style='text-align: left;'>确定 api 协议</td>
#       <td style='text-align: left;'>缓冲区</td>
#     </tr>
#   </tbody>
# </table>
#
# - 附：本周实际工作：
#
# <table>
#   <thead>
#     <tr>
#       <th style='text-align: center;'></th>
#       <th style='text-align: center;'>六</th>
#       <th style='text-align: center;'>一</th>
#       <th style='text-align: center;'>二</th>
#       <th style='text-align: center;'>三</th>
#       <th style='text-align: center;'>四</th>
#       <th style='text-align: center;'>五</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style='text-align: left;'>上午</td>
#       <td style='text-align: left;'>与手表开发者联调</td>
#       <td style='text-align: left;'>寻找（结束呼叫事务）<br>失败原因<br>+<br>修正树莓派只读系统<br>自动构建脚本 bug</td>
#       <td style='text-align: left;'>为树莓派技术支持<br>提供支持<br>+<br>与少志联调呼叫器</td>
#       <td style='text-align: left;'>解决 VIG9002 网络<br>不能设置的问题</td>
#       <td style='text-align: left;'>解决 VIG9002 手表<br>不能注册的问题</td>
#       <td rowspan="2" style='text-align: left;'>周报写于当天，<br>故周五计入下周周报</td>
#     </tr>
#     <tr>
#       <td style='text-align: left;'>下午</td>
#       <td style='text-align: left;'>寻找（结束呼叫事务）<br>失败原因</td>
#       <td style='text-align: left;'>与手表开发者联调</td>
#       <td style='text-align: left;'>商务发货树莓派，帮忙升级<br>+<br>修正树莓派只读系统<br>自动构建脚本 bug<br>+<br>分解云平台 API 开发任务</td>
#       <td style='text-align: left;'>解决 VIG9002 网络<br>不能设置的问题</td>
#       <td style='text-align: left;'>解决 VIG9002 手表<br>不能注册的问题</td>
#     </tr>
#   </tbody>
# </table>
#
# #### 3. **人脸库完成度详情**
#
# 　　第一版完成，已准备投入测试。
#
# #### 4. **云平台下周计划**
#
# <table>
#   <thead>
#     <tr>
#       <th style='text-align: center;'></th>
#       <th style='text-align: center;'>五</th>
#       <th style='text-align: center;'>日</th>
#       <th style='text-align: center;'>一</th>
#       <th style='text-align: center;'>二</th>
#       <th style='text-align: center;'>三</th>
#       <th style='text-align: center;'>四</th>
#       <th style='text-align: center;'>五</th>
#       <th style='text-align: center;'>六</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style='text-align: left;'>上午</td>
#       <td style='text-align: left;'>解决 VIG9002 <br>网络设置问题</td>
#       <td style='text-align: center;'>-</td>
#       <td style='text-align: left;'>编写 <br>API 框架</td>
#       <td style='text-align: left;'>编写 <br>API 框架</td>
#       <td style='text-align: left;'>测试 <br>API 框架</td>
#       <td style='text-align: left;'>编写 <br>API 业务：<br>get 请求及其<br>响应符合协议<br>和业务需求</td>
#       <td style='text-align: left;'>编写 <br>API 业务：<br>get 请求及其<br>响应符合协议<br>和业务需求</td>
#       <td rowspan="2" style='text-align: left;'>周报预计<br>写于当天<br>故周五计入<br>下周周报</td>
#     </tr>
#     <tr>
#       <td style='text-align: left;'>下午</td>
#       <td style='text-align: left;'>主机和门口机<br>外包讨论会</td>
#       <td style='text-align: left;'>解决 VIG9002 <br>网络设置问题</td>
#       <td style='text-align: left;'>编写 <br>API 框架</td>
#       <td style='text-align: left;'>编写 <br>API 框架</td>
#       <td style='text-align: left;'>测试 <br>API 框架</td>
#       <td style='text-align: left;'>编写 <br>API 业务：<br>get 请求及其<br>响应符合协议<br>和业务需求</td>
#       <td style='text-align: left;'>编写 <br>API 业务：<br>get 请求及其<br>响应符合协议<br>和业务需求</td>
#     </tr>
#   </tbody>
# </table>
#
# 　　注：该计划可能受到以下影响而变形：
#
# 1. 为车间和客户的部署提供技术支持等额外事项。
#
# 2. 随机出现的 VIG9002 网关维护工作。
