# %% [markdown]
# ___
# ### <span style='color: #dd4b39;'>完成了上周安排的哪些工作</span>
#
# 1. **树莓派只读系统测试（进度99%）**
#
#   - 测试：系统抗断电能力正常（100次呼叫中断电，100次通话中断电，正常率达到99%），导入数据无异常，并为系统添加周期备份数据库任务
#   - 已整理开发文档，便于今后查阅
#   - 已编写一个自动构建脚本，适应在2种情况（车间生产中和用户使用中）无损构建该只读系统
#   - 已经（通过戴工）通知车间可以升级，已经（通过李德平和连佳伟）关注树莓派客户反馈（当出现相关问题时，可以升级为只读系统）
#   - **应交付情况**：
#     - 测试报告——已经（通过戴工）通知测试部整理，会跟进
#     - 车间和客户已升级确认——已通知车间和客户，会持续得到确认
#     - 部署文档——已悉数上传至 ownCloud，包括：
#       - 1个该系统的[镜像文件](http://192.168.38.165:8080/index.php/f/67772)（.img 用于在 windows 下还原）
#       - 1个该系统的[备份文件](http://192.168.38.165:8080/index.php/f/67760)（.gz 用于在 linux 下还原）
#       - 1篇[部署指南](http://192.168.38.165:8080/index.php/f/67762)
#       - 1段[指导视频](http://192.168.38.165:8080/index.php/f/67764)
#       - 1个[自动构建程序包](http://192.168.38.165:8080/index.php/f/67763)
# <br><br>
# 2. **香橙派只读系统部署与测试（进度70%）**
#
#   - 部署初步完毕：系统挂载为只读，部分运行程序和数据库的目录挂载为读写，[参考](https://wiki.debian.org/ReadonlyRoot#Enable_readonly_root)
#   - 一个自动部署该系统的脚本（80%，目前遇到 node 因为某个库被我的脚本卸载了而无法运行）
# ___
# ### <span style='color: #dd4b39;'>未完成上周安排的哪些工作，和导致未完成的障碍</span>
#
# #### 1. 情况：
# - **树莓派只读系统测试（遗留1%）**
#
#  - 遗留的 1% 为后续的跟进和为构建该系统提供技术支持
# <br><br>
# - **香橙派只读系统部署与测试（遗留30%）**
#
#  - 测试未完毕，尚未为库存和客户升级
#  - 未整理开发文档，便于今后查阅
#  - **待交付**：测试报告、仓库和客户已升级确认、开发文档
# <br><br>
# - **云平台后端与前端开发（遗留100%）**
#
#  - 未开始
#
# #### 2. 原因：
#
# 1. 上周没有考虑到要为两种只读系统的构建分别做一个自动化脚本（它们的编写和自己测试分别花去了 1 天时间）
# 2. 周一下午有客户的树莓派服务器出现问题，前去解决，已解决（原因是空间不足，我给它挂载了硬盘，部署了自动定时备份和清理任务）
#
# 　　附：上周的时间记录：
#
# <table>
#   <thead>
#     <tr>
#       <th style='text-align: center;'></th>
#       <th style='text-align: center;'>六</th>
#       <th style='text-align: center;'>一</th>
#       <th style='text-align: center;'>二</th>
#       <th style='text-align: center;'>三</th>
#       <th style='text-align: center;'>四</th>
#       <th style='text-align: center;'>五</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style='text-align: left;'>上午</td>
#       <td style='text-align: left;'>部署了树莓派只读系统<br>给测试部测了300次</td>
#       <td style='text-align: left;'>接收测试反馈，<br>完善了树莓派只读系统</td>
#       <td style='text-align: left;'>编写树莓派只读系统<br>自动部署脚本，<br>自行测试该脚本</td>
#       <td style='text-align: left;'>编写树莓派只读系统<br>部署操作文档</td>
#       <td style='text-align: left;'>编写香橙派只读系统<br>自动部署脚本，<br>自行测试该脚本</td>
#       <td rowspan="2" style='text-align: left;'>周报写于当天<br>故周五计入<br>下周周报</td>
#     </tr>
#     <tr>
#       <td style='text-align: left;'>下午</td>
#       <td style='text-align: left;'>解决测试部对该系统<br>反馈的问题</td>
#       <td style='text-align: left;'>为一个客户远程解决<br>树莓派 web 端<br>无法访问的问题</td>
#       <td style='text-align: left;'>为香橙派部署只读系统</td>
#       <td style='text-align: left;'>编写树莓派只读系统<br>自动部署脚本，<br>自行测试该脚本</td>
#       <td style='text-align: left;'>编写香橙派派只读系统<br>自动部署脚本，<br>自行测试该脚本</td>
#     </tr>
#   </tbody>
# </table>
#
# ___
# ### <span style='color: #dd4b39;'>额外完成了哪些上周未安排的工作</span>
#
# 1. 为两种只读系统的构建分别做了一个自动化脚本
# 2. 为一个客户的树莓派服务器解决了无法正常运行的问题
# ___
# ### <span style='color: #dd4b39;'>准备下周要完成哪些工作</span>
#
# #### 1. . 香橙派只读系统部署与测试
#
# - 继续完善自动构建脚本
# - 测试：安排测试，并根据测试反馈进行修正
# - 测试完毕，为美国客户升级（**备忘**：别忘了先备份数据！）
# - 整理：整理开发文档
# - **应交付**：测试报告、客户已升级确认、开发文档
#
# #### 2. 云平台后端与前端开发
#   全部工作分为：阅读已有源码、明确医疗项目需求、任务安排、执行、跟踪、交付。
#   下周主要工作为：
# - 阅读已有源码（**备忘**：与张工多交流，他是作者）
# - 明确医疗项目需求（**备忘**：与阿秋多交流，他是产品经理）
# - 云平台开发任务安排到禅道（**备忘**：向会用的人请教）
# - 更新和跟进开发文档（**备忘**：告警、事件、动作等，用 VuePress）
# - **应交付**：交流纪要（如需）、在禅道上的相关任务列表
#
# 　　附：预期下周时间记录概览：
#
# <table>
#   <thead>
#     <tr>
#       <th style='text-align: center;'></th>
#       <th style='text-align: center;'>五</th>
#       <th style='text-align: center;'>一</th>
#       <th style='text-align: center;'>二</th>
#       <th style='text-align: center;'>三</th>
#       <th style='text-align: center;'>四</th>
#       <th style='text-align: center;'>五</th>
#       <th style='text-align: center;'>六</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style='text-align: left;'>下午</td>
#       <td style='text-align: left;'>部署了香橙派只读系统<br>给测试部测了n次</td>
#       <td style='text-align: left;'>完成香橙派只读系统<br>部署与测试（上）</td>
#       <td style='text-align: left;'>本周云平台开发任务：<br>阅读源码</td>
#       <td style='text-align: left;'>本周云平台开发任务：<br>明确需求</td>
#       <td style='text-align: left;'>本周云平台开发任务：<br>时间表</td>
#       <td style='text-align: left;'>本周云平台开发任务：<br>缓冲 或 按时间表执行</td>
#       <td rowspan="2" style='text-align: left;'>周报预计<br>写于当天<br>故周六计入<br>下周周报</td>
#     </tr>
#     <tr>
#       <td style='text-align: left;'>上午</td>
#       <td style='text-align: left;'>接收测试反馈，<br>完善香橙派只读系统</td>
#       <td style='text-align: left;'>完成香橙派只读系统<br>部署与测试（下）</td>
#       <td style='text-align: left;'>本周云平台开发任务：<br>阅读源码</td>
#       <td style='text-align: left;'>本周云平台开发任务：<br>安排禅道</td>
#       <td style='text-align: left;'>本周云平台开发任务：<br>缓冲 或 按时间表执行</td>
#       <td style='text-align: left;'>本周云平台开发任务：<br>缓冲 或 按时间表执行</td>
#     </tr>
#   </tbody>
# </table>
#
# 　　注：缓冲区可能用于：为车间和客户的部署提供技术支持等额外事项。
#
# ___
# ### <span style='color: #dd4b39;'>其他任何事项（意见建议、感想备忘、吐槽抱怨皆可）</span>
#
# 　　（暂无）
