# %% [markdown]
# ___
# ### <span style='color: #dd4b39;'>完成了上周安排的哪些工作</span>
#
# 1. **香橙派只读系统部署与测试（进度99%）**
#
#   - 系统部署完毕，内部程序正常运行，测试部正在测试（已在非呼叫状态下测 30 次无异常）
#   - 一个自动部署该系统的脚本（100%）
# <br><br>
# 2. **云平台后端与前端开发（进度10%）**
#
#   - 源码基本阅读完毕（90%，包括整体架构、web/api细节、通讯协议工作原理及实现等）——在张工指导下
# <br><br>
# 3. **树莓派只读系统测试**
#
#   - 培训了技术支持（现场演示 + 复习视频）
#
# ___
# ### <span style='color: #dd4b39;'>未完成上周安排的哪些工作，和导致未完成的障碍</span>
#
# #### 1. 情况：
# - **云平台后端与前端开发（遗留90%）**
#
#  - 任务未分解，时间表未确定
#  - web/api 相关工作未开始（旧协议需要修改）
#  - vimp 通信相关工作未开始（告警、事件、动作等相关文档未开始；但文档工具 Vuepress 已部署成功）
#  - web 前端相关工作未开始
# <br><br>
# - **树莓派只读系统测试（遗留1%）**
#
#  - 遗留的 1% 为后续的测试跟进和为构建该系统提供技术支持
# <br><br>
# - **香橙派只读系统部署与测试（遗留1%）**
#
#  - 遗留的 1% 为后续的测试跟进和为构建该系统提供技术支持
#
# #### 2. 原因：
#
# 　　基本按照上周安排进行。只是：
#
# - 周三下午请假；
# <br><br>
# - 周四原计划分解任务和制定时间表，实际：
#
#     1. 协助技术支持解决内蒙古客户树莓派问题——上午
#     2. 参与关于 VIG9002 空中协议通信优化的讨论——下午
#     3. 参与关于 VIG9002 空中协议通信优化的实施（具体要改哪部分源码）——晚上
# <br><br>
# - 周五早上参与讨论医疗项目的通信协议（用 FS 实现还是私有协议）；下午参与外包相关技术讨论。
# <br><br>
# - 附：上周原计划：
#
# <table>
#   <thead>
#     <tr>
#       <th style='text-align: center;'></th>
#       <th style='text-align: center;'>五</th>
#       <th style='text-align: center;'>一</th>
#       <th style='text-align: center;'>二</th>
#       <th style='text-align: center;'>三</th>
#       <th style='text-align: center;'>四</th>
#       <th style='text-align: center;'>五</th>
#       <th style='text-align: center;'>六</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style='text-align: left;'>上午</td>
#       <td style='text-align: left;'>部署了香橙派只读系统<br>给测试部测了n次</td>
#       <td style='text-align: left;'>完成香橙派只读系统<br>部署与测试（上）</td>
#       <td style='text-align: left;'>本周云平台开发任务：<br>阅读源码</td>
#       <td style='text-align: left;'>本周云平台开发任务：<br>明确需求</td>
#       <td style='text-align: left;'>本周云平台开发任务：<br>时间表</td>
#       <td style='text-align: left;'>本周云平台开发任务：<br>缓冲 或 按时间表执行</td>
#       <td rowspan="2" style='text-align: left;'>周报预计<br>写于当天<br>故周六计入<br>下周周报</td>
#     </tr>
#     <tr>
#       <td style='text-align: left;'>下午</td>
#       <td style='text-align: left;'>接收测试反馈，<br>完善香橙派只读系统</td>
#       <td style='text-align: left;'>完成香橙派只读系统<br>部署与测试（下）</td>
#       <td style='text-align: left;'>本周云平台开发任务：<br>阅读源码</td>
#       <td style='text-align: left;'>本周云平台开发任务：<br>安排禅道</td>
#       <td style='text-align: left;'>本周云平台开发任务：<br>缓冲 或 按时间表执行</td>
#       <td style='text-align: left;'>本周云平台开发任务：<br>缓冲 或 按时间表执行</td>
#     </tr>
#   </tbody>
# </table>
#
# ___
# ### <span style='color: #dd4b39;'>额外完成了哪些上周未安排的工作</span>
#
# 1. 协助技术支持解决内蒙古客户树莓派问题
# 2. 参与关于 VIG9002 空中协议通信优化的讨论
# 3. 参与关于 VIG9002 空中协议通信优化的实施（具体要改哪部分源码）
# 4. 参与讨论医疗项目的通信协议（用 FS 实现还是私有协议）
# 5. 参与外包相关技术讨论。
# ___
# ### <span style='color: #dd4b39;'>准备下周要完成哪些工作</span>
#
# #### 1. 云平台后端与前端开发
#  - 分解任务，制定时间表
#  - web/api 相关工作（阅读 nebd 和 jsonpath 使用文档；原先代码的试运行；确定api协议等）
#  - vimp 通信相关工作（阅读协议文档；编写告警、事件、动作等相关文档等）
#  - web 前端相关工作
#
# #### 2. VIG9002 网关维护工作
#  - 协助呼叫器与手表开发者联调
#  - 接收测试部反馈问题并解决
#
# 　　附：预期下周时间记录概览：
#
# <table>
#   <thead>
#     <tr>
#       <th style='text-align: center;'></th>
#       <th style='text-align: center;'>六</th>
#       <th style='text-align: center;'>一</th>
#       <th style='text-align: center;'>二</th>
#       <th style='text-align: center;'>三</th>
#       <th style='text-align: center;'>四</th>
#       <th style='text-align: center;'>五</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style='text-align: left;'>上午</td>
#       <td style='text-align: left;'>分解任务<br>制定时间表<br>初步</td>
#       <td style='text-align: left;'>阅读 nebd <br>和 jsonpath</td>
#       <td style='text-align: left;'>阅读协议文档</td>
#       <td style='text-align: left;'>编写告警、<br>事件、<br>动作等相关文档</td>
#       <td style='text-align: left;'>缓冲区</td>
#       <td rowspan="2" style='text-align: left;'>周报预计<br>写于当天<br>故周五计入<br>下周周报</td>
#     </tr>
#     <tr>
#       <td style='text-align: left;'>下午</td>
#       <td style='text-align: left;'>确定分解任务合理性<br>确定时间表可行性<br>后执行</td>
#       <td style='text-align: left;'>试运行原有的<br> web/api 代码</td>
#       <td style='text-align: left;'>理解既定<br>业务数据模型</td>
#       <td style='text-align: left;'>确定 api 协议</td>
#       <td style='text-align: left;'>缓冲区</td>
#     </tr>
#   </tbody>
# </table>
#
# 　　注：缓冲区可能用于：
#
# 1. 为车间和客户的部署提供技术支持等额外事项。
#
# 2. 随机出现的 VIG9002 网关维护工作。
#
# ___
# ### <span style='color: #dd4b39;'>其他任何事项（意见建议、感想备忘、吐槽抱怨皆可）</span>
#
# 　　（暂无）

# %% [markdown]
# <table>
#   <thead>
#     <tr>
#       <th style='text-align: center;'></th>
#       <th style='text-align: center;'>六</th>
#       <th style='text-align: center;'>一</th>
#       <th style='text-align: center;'>二</th>
#       <th style='text-align: center;'>三</th>
#       <th style='text-align: center;'>四</th>
#       <th style='text-align: center;'>五</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style='text-align: left;'>上午</td>
#       <td style='text-align: left;'>与手表开发者联调</td>
#       <td style='text-align: left;'>寻找（结束呼叫事务）<br>失败原因<br>+<br>修正树莓派只读系统<br>自动构建脚本 bug</td>
#       <td style='text-align: left;'>为树莓派技术支持<br>提供支持<br>+<br>与少志联调呼叫器</td>
#     </tr>
#     <tr>
#       <td style='text-align: left;'>下午</td>
#       <td style='text-align: left;'>寻找（结束呼叫事务）<br>失败原因</td>
#       <td style='text-align: left;'>与手表开发者联调</td>
#       <td style='text-align: left;'>商务发货树莓派，帮忙升级<br>+<br>修正树莓派只读系统<br>自动构建脚本 bug<br>+<br>分解云平台开发任务</td>
#     </tr>
#   </tbody>
# </table>
