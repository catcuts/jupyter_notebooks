// %% [markdown]
// >[来源](https://www.nowcoder.com/test/question/done?tid=15071626&qid=56249#referAnchor)

// %% [markdown]
// 以下 javascript 代码执行后， 浏览器 console 出来的结果分别是

// %%
console.log('\n'.repeat(100))
var color = 'greeen';
var test4399 = {
  color: 'blue',
  getColor: function(){
    var color = 'red';
    console.log("\x1b[37m%s\x1b[0m", this.color);
  },
}
var getColor = test4399.getColor;  // 注意: 函数赋值, 执行的时候才会去取 this
getColor();  // 执行的时候才会去取 this, 但此时的 this 是 window 而不是 test4399
test4399.getColor();  // 这样执行时的 this 才是 test4399
// Out:
// greeen
// blue
